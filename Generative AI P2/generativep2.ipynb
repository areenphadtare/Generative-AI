# %%
pip install -q langchain-openai langchain-core requests
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.8/571.8 kB 18.8 MB/s eta 0:00:00

# %%
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %% [markdown]
# ## Tool CREATE

# %%
@tool
def multiply_numbers(a: int, b: int) -> float:
    """Multiplies two numbers."""
    return a * b

# %%
print(multiply_numbers.invoke({"a": 3, "b": 4}))  # Output: 12
# Out:
# 12

# %%
multiply_numbers.description
# Out:
# 'Multiplies two numbers.'

# %%
multiply_numbers.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %% [markdown]
# ### Tool Binding

# %%
llm = ollama(sk-proj-ho_1C2yhR8BVngFg6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1989/2451363123.py in <cell line: 0>()
# ----> 1 llm = ollama(model="llama3", base_url="http://localhost:11434")
#
# NameError: name 'ollama' is not defined

# %%
llm_with_tools=llm.bind_tools([multiply_numbers])

# %%
llm_with_tools

# %%
llm_with_tools.invoke('hi how are you?')
