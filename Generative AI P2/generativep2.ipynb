# %%
import os
os.environ["OPENAI_API_KEY"]="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"

# %%
pip install -q langchain-openai langchain-core requests
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 3.5 MB/s eta 0:00:00

# %%
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %% [markdown]
# ## Tool CREATE

# %%
@tool
def multiply_numbers(a: int, b: int) -> float:
    """Multiplies two numbers."""
    return a * b

# %%
print(multiply_numbers.invoke({"a": 3, "b": 4}))  # Output: 12
# Out:
# 12

# %%
multiply_numbers.description
# Out:
# 'Multiplies two numbers.'

# %%
multiply_numbers.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %% [markdown]
# ### Tool Binding

# %%
llm = ChatOpenAI()

# %%
llm_with_tools=llm.bind_tools([multiply_numbers])

# %%
llm_with_tools
# Out:
# _ChatModelBinding(bound=ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.0', 'langchain': '1.3.17', 'langchain-openai': '1.6.0'}}, profile={'name': 'GPT-3.5-turbo', 'status': 'deprecated', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x7e6041b14ad0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7e6041b15550>, root_
# ...

# %%
llm_with_tools.invoke('hi how are you?')
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/langchain_openai/chat_models/base.py in _generate(self, messages, stop, run_manager, **kwargs)
#    1879             else:
# -> 1880                 raw_response = self.client.with_raw_response.create(**payload)
#    1881                 response = raw_response.parse()
#
# /usr/local/lib/python3.13/dist-packages/openai/_legacy_response.py in wrapped(*args, **kwargs)
#     368
# --> 369         return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#     370
#
# /usr/local/lib/python3.13/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     297                 raise TypeError(msg)
# --> 298             return func(*args, **kwargs)
#     299
#
# ...
